# %% [markdown]
# # ColorAI — Deep Image Colorization Training on Google Colab
# **Project:** Deep Image Colorization Using U-Net in CIE Lab Color Space
# **Course:** Neural Networks & Deep Learning (7th Sem Mini Project)
#
# Run this notebook on Google Colab with **GPU Runtime (T4)** to train the `ColorizationUNet` and download `best.pth`.

# %% [markdown]
# ### Step 1: Check GPU Acceleration

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Clone the Project Repository

# %%
# !git clone https://github.com/codeby-arsb/nndl-mini-project.git
# %cd nndl-mini-project
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 3: Download ADE20K Dataset

# %%
# !python scripts/download_dataset.py
# !python scripts/verify_setup.py

# %% [markdown]
# ### Step 4: Train the Baseline U-Net Model (MSE Loss / Automatic Mixed Precision)

# %%
# !python -m src.train --epochs 20 --batch-size 16 --amp

# %% [markdown]
# ### Step 5: Download the Trained `best.pth` Checkpoint
# Once training completes, download `outputs/checkpoints/best.pth` and drag-and-drop it into the **ColorAI Web Studio**!

# %%
from google.colab import files
files.download('outputs/checkpoints/best.pth')
